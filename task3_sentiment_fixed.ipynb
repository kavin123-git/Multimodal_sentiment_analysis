# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Define paths
zip_path = "/content/drive/MyDrive/images.zip"  # Update with correct file name
extract_path = "/content/images"  # Destination folder

# Create extraction directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Extract zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction Complete! Files are in:", extract_path)
# Out:
# Extraction Complete! Files are in: /content/images

# %%
# !pip install transformers timm torch torchvision pandas pillow

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision import models
from transformers import AutoModel, AutoTokenizer
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import pandas as pd
import os
import numpy as np
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.14)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 60.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import os
import pandas as pd
from PIL import Image

def clean_dataset(csv_file_path, img_dir_path):
    """
    Cleans the dataset by removing images that cannot be read or have empty captions.

    Args:
        csv_file_path (str): Path to the CSV file containing image labels.
        img_dir_path (str): Path to the directory containing the images.
    """
    df = pd.read_csv(csv_file_path)

    # Filter out images with issues:
    indices_to_remove = []
    for index, row in df.iterrows():
        img_name = os.path.join(img_dir_path, str(row['image_name']))  # Assuming 'image_name' column
        caption = row['text_corrected']  # Assuming 'text_corrected' column

        # Check for empty caption:
        if not isinstance(caption, str) or not caption.strip():
            print(f"Removing entry with empty or invalid caption: {img_name}")
            indices_to_remove.append(index)
            continue

        # Check if image can be read:
        try:
            Image.open(img_name).convert("RGB")
        except (FileNotFoundError, IOError, OSError):
            print(f"Removing entry with unreadable image: {img_name}")
            indices_to_remove.append(index)
            # Optional: If you want to delete the image file itself:
            # os.remove(img_name)

    # Remove problematic entries from DataFrame:
    cleaned_df = df.drop(indices_to_remove)

    # Overwrite original CSV file with cleaned data:
    cleaned_df.to_csv(csv_file_path, index=False)

    print(f"Removed {len(indices_to_remove)} entries from the dataset.")

# %%
# Change these paths to match your dataset location
CSV_FILE_PATH = "/content/labels.csv"  # Replace with actual path
IMG_DIR_PATH = "/content/images"  # Replace with actual path

# %%
# Image Preprocessing
image_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load Pretrained Tokenizer (BERT/RoBERTa)
TEXT_MODEL = "bert-base-uncased"  # Change to "roberta-base" if using RoBERTa
tokenizer = AutoTokenizer.from_pretrained(TEXT_MODEL)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
class MemeDataset(Dataset):
    def __init__(self, csv_file, img_dir, tokenizer, transform=None, max_length=128):
        self.data = pd.read_csv(csv_file)
        self.img_dir = img_dir
        self.tokenizer = tokenizer
        self.transform = transform
        self.max_length = max_length

        # Label Mapping
        self.label_mapping = {
            "not_funny": 0, "funny": 1, "very_funny": 2, "hilarious": 3,
            "not_sarcastic": 0, "general": 1, "twisted_meaning": 2, "very_twisted": 3,
            "not_offensive": 0, "slight": 1, "very_offensive": 2, "hateful_offensive": 3,
            "not_motivational": 0, "motivational": 1
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        try:
            # Load Image
            img_name = os.path.join(self.img_dir, str(self.data.iloc[idx, 0]))
            image = Image.open(img_name).convert("RGB")
            if self.transform:
                image = self.transform(image)

            # Process Text
            caption = self.data.iloc[idx, 2]  # "text_corrected"
            if not isinstance(caption, str):
                caption = str(caption)  # Convert to string if necessary

            # Check if caption is empty and skip if it is
            if not caption.strip():
                print(f"Skipping empty caption for image: {img_name}")
                raise FileNotFoundError  # Reuse FileNotFoundError for consistency

            encoding = self.tokenizer(caption, padding="max_length", truncation=True, max_length=self.max_length, return_tensors="pt")
            text_input_ids = encoding["input_ids"].squeeze(0)
            text_attention_mask = encoding["attention_mask"].squeeze(0)

            # Map Labels
            humor = self.label_mapping.get(str(self.data.iloc[idx, 3]), -1)  # Default -1 for errors
            sarcasm = self.label_mapping.get(str(self.data.iloc[idx, 4]), -1)
            offense = self.label_mapping.get(str(self.data.iloc[idx, 5]), -1)
            motivation = self.label_mapping.get(str(self.data.iloc[idx, 6]), -1)

            labels = torch.tensor([humor, sarcasm, offense, motivation], dtype=torch.float32)

            return text_input_ids, text_attention_mask, image, labels

        except FileNotFoundError:
            print(f"File not found or empty caption: {img_name}, skipping...")
            # Instead of returning empty tensors, return tensors with valid token IDs
            return torch.zeros(self.max_length, dtype=torch.long), torch.zeros(self.max_length, dtype=torch.long), torch.zeros(3, 224, 224, dtype=torch.float32), torch.tensor([-1, -1, -1, -1], dtype=torch.float32)

# %%
# Create Dataset & DataLoader
clean_dataset(CSV_FILE_PATH, IMG_DIR_PATH)
dataset = MemeDataset(CSV_FILE_PATH, IMG_DIR_PATH, tokenizer, transform=image_transform)
# Check a sample batch
for text_input_ids, text_attention_mask, images, labels in dataloader:
    print("Text input shape:", text_input_ids.shape)  # (batch_size, max_length)
    print("Image shape:", images.shape)  # (batch_size, 3, 224, 224)
    print("Labels shape:", labels.shape)  # (batch_size, 4)
    break
# Out:
# Streaming output truncated to the last 5000 lines.
# Removing entry with unreadable image: /content/images/image_2005.jpeg
# Removing entry with unreadable image: /content/images/image_2006.jpg
# Removing entry with unreadable image: /content/images/image_2007.png
# Removing entry with unreadable image: /content/images/image_2008.png
# Removing entry with unreadable image: /content/images/image_2009.png
# Removing entry with unreadable image: /content/images/image_2010.jpg
# Removing entry with unreadable image: /content/images/image_2011.png
# Removing entry with unreadable image: /content/images/image_2012.png
# Removing entry with unreadable image: /content/images/image_2013.jpg
# Removing entry with unreadable image: /content/images/image_2014.png
# Removing entry with unreadable image: /content/images/image_2015.jpg
# Removing entry with unreadable image: /content/images/image_2016.jpg
# Removing entry with unreadable image: /content/images/image_2017.jpg
# Removing entry with unreadable image: /content/images/image_2018.png
# Removing entry with unreadable image: /content/images/image_2019.jpg
# Removing entry with unreadable image: /content/images/image_2020.png
# Removing entry with unreadable image: /content/images/image_2021.png
# Removing entry with unreadable image: /content/images/image_2022.jpg
# Removing entry with unreadable image: /content/images/image_2023.jpg
# Removing entry with unreadable image: /content/images/image_2024.png
# Removing entry with unreadable image: /content/images/image_2025.png
# Removing entry with unreadable image: /content/images/image_2026.jpg
# Removing entry with unreadable image: /content/images/image_2027.png
# Removing entry with unreadable image: /content/images/image_2028.png
# Removing entry with unreadable image: /content/images/image_2029.png
# Removing entry with unreadable image: /content/images/image_2030.jpg
# Removing entry with unreadable image: /content/images/image_2031.png
# Removing entry with unreadable image: /content/images/image_2032.png
# Removing entry with unreadable image: /content/images/image_2033.png
# Removing entry with unreadable image: /content/images/image_2034.png
# Removing entry with unreadable image: /content/images/image_2035.jpg
# Removing entry with unreadable image: /content/images/image_2036.png
# Removing entry with unreadable image: /content/images/image_2037.jpg
# Removing entry with unreadable image: /content/images/image_2038.jpg
# Removing entry with unreadable image: /content/images/image_2039.jpg
# Removing entry with unreadable image: /content/images/image_2040.jpg
# Removing entry with unreadable image: /content/images/image_2041.jpg
# Removing entry with unreadable image: /content/images/image_2042.jpg
# Removing entry with unreadable image: /content/images/image_2043.jpeg
# Removing entry with unreadable image: /content/images/image_2044.jpeg
# Removing entry with unreadable image: /content/images/image_2045.jpg
# Removing entry with unreadable image: /content/images/image_2046.jpg
# Removing entry with unreadable image: /content/images/image_2047.jpg
# Removing entry with unreadable image: /content/images/image_2048.jpg
# Removing entry with unreadable image: /content/images/image_2049.jpg
# Removing entry with unreadable image: /content/images/image_2050.jpg
# Removing entry with unreadable image: /content/images/image_2051.jpg
# Removing entry with unreadable image: /content/images/image_2052.jpg
# Removing entry with unreadable image: /content/images/image_2053.jpg
# Removing entry with unreadable image: /content/images/image_2054.jpg
# Removing entry with unreadable image: /content/images/image_2055.jpg
# Removing entry with unreadable image: /content/images/image_2056.jpg
# Removing entry with unreadable image: /content/images/image_2057.jpg
# Removing entry with unreadable image: /content/images/image_2058.jpg
# Removing entry with unreadable image: /content/images/image_2059.jpg
# Removing entry with unreadable image: /content/images/image_2060.jpg
# Removing entry with unreadable image: /content/images/image_2061.jpg
# Removing entry with unreadable image: /content/images/image_2062.jpg
# Removing entry with unreadable image: /content/images/image_2063.jpg
# Removing entry with unreadable image: /content/images/image_2064.jpg
# Removing entry with unreadable image: /content/images/image_2065.jpg
# Removing entry with unreadable image: /content/images/image_2066.png
# Removing entry with unreadable image: /content/images/image_2067.jpg
# Removing entry with unreadable image: /content/images/image_2068.jpg
# Removing entry with unreadable image: /content/images/image_2069.jpg
# Removing entry with unreadable image: /content/images/image_2070.jpg
# Removing entry with unreadable image: /content/images/image_2071.png
# Removing entry with unreadable image: /content/images/image_2072.png
# Removing entry with unreadable image: /content/images/image_2073.jpg
# Removing entry with unreadable image: /content/images/image_2074.jpg
# Removing entry with unreadable image: /content/images/image_2075.jpg
# Removing entry with unreadable image: /content/images/image_2076.png
# Removing entry with unreadable image: /content/images/image_2077.jpg
# Removing entry with unreadable image: /content/images/image_2078.jpg
# Removing entry with unreadable image: /content/images/image_2079.jpg
# Removing entry with unreadable image: /content/images/image_2080.jpg
# Removing entry with unreadable image: /content/images/image_2081.jpg
# Removing entry with unreadable image: /content/images/image_2082.jpg
# Removing entry with unreadable image: /content/images/image_2083.jpg
# Removing entry with unreadable image: /content/images/image_2084.jpg
# Removing entry with unreadable image: /content/images/image_2085.png
# Removing entry with unreadable image: /content/images/image_2086.jpg
# Removing entry with unreadable image: /content/images/image_2087.jpg
# Removing entry with unreadable image: /content/images/image_2088.jpg
# Removing entry with unreadable image: /content/images/image_2089.jpg
# Removing entry with unreadable image: /content/images/image_2090.jpg
# Removing entry with unreadable image: /content/images/image_2091.png
# Removing entry with unreadable image: /content/images/image_2092.png
# Removing entry with unreadable image: /content/images/image_2093.jpg
# Removing entry with unreadable image: /content/images/image_2094.jpg
# Removing entry with unreadable image: /content/images/image_2095.jpg
# Removing entry with unreadable image: /content/images/image_2096.jpg
# Removing entry with unreadable image: /content/images/image_2097.jpg
# Removing entry with unreadable image: /content/images/image_2098.jpg
# Removing entry with unreadable image: /content/images/image_2099.jpg
# Removing entry with unreadable image: /content/images/image_2100.jpg
# Removing entry with unreadable image: /content/images/image_2101.png
# Removing entry with unreadable image: /content/images/image_2102.jpg
# Removing entry with unreadable image: /content/images/image_2103.jpg
# Removing entry with unreadable image: /content/images/image_2104.jpg
# Removing entry with unreadable image: /content/images/image_2105.jpg
# Removing entry with unreadable image: /content/images/image_2106.png
# Removing entry with unreadable image: /content/images/image_2107.jpg
# Removing entry with unreadable image: /content/images/image_2108.jpg
# Removing entry with unreadable image: /content/images/image_2109.jpg
# Removing entry with unreadable image: /content/images/image_2110.jpg
# Removing entry with unreadable image: /content/images/image_2111.jpg
# Removing entry with unreadable image: /content/images/image_2112.png
# Removing entry with unreadable image: /content/images/image_2113.png
# Removing entry with unreadable image: /content/images/image_2114.jpg
# Removing entry with unreadable image: /content/images/image_2115.png
# Removing entry with unreadable image: /content/images/image_2116.jpg
# Removing entry with unreadable image: /content/images/image_2117.png
# Removing entry with unreadable image: /content/images/image_2118.jpg
# Removing entry with unreadable image: /content/images/image_2119.png
# Removing entry with unreadable image: /content/images/image_2120.jpg
# Removing entry with unreadable image: /content/images/image_2121.png
# Removing entry with unreadable image: /content/images/image_2122.png
# Removing entry with unreadable image: /content/images/image_2123.jpg
# Removing entry with unreadable image: /content/images/image_2124.png
# Removing entry with unreadable image: /content/images/image_2125.jpg
# Removing entry with unreadable image: /content/images/image_2126.png
# Removing entry with unreadable image: /content/images/image_2127.png
# Removing entry with unreadable image: /content/images/image_2128.png
# Removing entry with unreadable image: /content/images/image_2129.png
# Removing entry with unreadable image: /content/images/image_2130.jpg
# Removing entry with unreadable image: /content/images/image_2131.jpg
# Removing entry with unreadable image: /content/images/image_2132.png
# Removing entry with unreadable image: /content/images/image_2133.png
# Removing entry with unreadable image: /content/images/image_2134.png
# Removing entry with unreadable image: /content/images/image_2135.png
# Removing entry with unreadable image: /content/images/image_2136.png
# Removing entry with unreadable image: /content/images/image_2137.png
# Removing entry with unreadable image: /content/images/image_2138.png
# Removing entry with unreadable image: /content/images/image_2139.png
# Removing entry with unreadable image: /content/images/image_2140.jpg
# Removing entry with unreadable image: /content/images/image_2141.jpg
# Removing entry with unreadable image: /content/images/image_2142.jpg
# Removing entry with unreadable image: /content/images/image_2143.jpg
# Removing entry with unreadable image: /content/images/image_2144.jpg
# Removing entry with unreadable image: /content/images/image_2145.jpg
# Removing entry with unreadable image: /content/images/image_2146.jpg
# Removing entry with unreadable image: /content/images/image_2147.jpg
# Removing entry with unreadable image: /content/images/image_2148.jpeg
# Removing entry with unreadable image: /content/images/image_2149.jpg
# Removing entry with unreadable image: /content/images/image_2150.jpg
# Removing entry with unreadable image: /content/images/image_2151.jpeg
# Removing entry with unreadable image: /content/images/image_2152.jpeg
# Removing entry with unreadable image: /content/images/image_2153.png
# Removing entry with unreadable image: /content/images/image_2154.png
# Removing entry with unreadable image: /content/images/image_2155.jpeg
# Removing entry with unreadable image: /content/images/image_2156.jpg
# Removing entry with unreadable image: /content/images/image_2157.jpeg
# Removing entry with unreadable image: /content/images/image_2158.jpg
# Removing entry with unreadable image: /content/images/image_2159.jpg
# Removing entry with unreadable image: /content/images/image_2160.png
# Removing entry with unreadable image: /content/images/image_2161.jpg
# Removing entry with unreadable image: /content/images/image_2162.jpg
# Removing entry with unreadable image: /content/images/image_2163.jpg
# Removing entry with unreadable image: /content/images/image_2164.jpg
# Removing entry with unreadable image: /content/images/image_2165.jpg
# Removing entry with unreadable image: /content/images/image_2166.jpg
# Removing entry with unreadable image: /content/images/image_2167.jpg
# Removing entry with unreadable image: /content/images/image_2168.jpg
# Removing entry with unreadable image: /content/images/image_2169.png
# Removing entry with unreadable image: /content/images/image_2170.png
# Removing entry with unreadable image: /content/images/image_2171.jpg
# Removing entry with unreadable image: /content/images/image_2172.png
# Removing entry with unreadable image: /content/images/image_2173.png
# Removing entry with unreadable image: /content/images/image_2174.jpg
# Removing entry with unreadable image: /content/images/image_2175.png
# Removing entry with unreadable image: /content/images/image_2176.png
# Removing entry with unreadable image: /content/images/image_2177.png
# Removing entry with unreadable image: /content/images/image_2178.jpg
# Removing entry with unreadable image: /content/images/image_2179.png
# Removing entry with unreadable image: /content/images/image_2180.png
# Removing entry with unreadable image: /content/images/image_2181.jpg
# Removing entry with unreadable image: /content/images/image_2182.png
# Removing entry with unreadable image: /content/images/image_2183.jpg
# Removing entry with unreadable image: /content/images/image_2184.png
# Removing entry with unreadable image: /content/images/image_2185.jpg
# Removing entry with unreadable image: /content/images/image_2186.png
# Removing entry with unreadable image: /content/images/image_2187.png
# Removing entry with unreadable image: /content/images/image_2188.png
# Removing entry with unreadable image: /content/images/image_2189.png
# Removing entry with unreadable image: /content/images/image_2190.png
# Removing entry with unreadable image: /content/images/image_2191.jpg
# Removing entry with unreadable image: /content/images/image_2192.jpg
# Removing entry with unreadable image: /content/images/image_2193.png
# Removing entry with unreadable image: /content/images/image_2194.png
# Removing entry with unreadable image: /content/images/image_2195.png
# Removing entry with unreadable image: /content/images/image_2196.png
# Removing entry with unreadable image: /content/images/image_2197.png
# Removing entry with unreadable image: /content/images/image_2198.jpg
# Removing entry with unreadable image: /content/images/image_2199.jpg
# Removing entry with unreadable image: /content/images/image_2200.jpg
# Removing entry with unreadable image: /content/images/image_2201.jpg
# Removing entry with unreadable image: /content/images/image_2202.jpg
# Removing entry with unreadable image: /content/images/image_2203.jpeg
# Removing entry with unreadable image: /content/images/image_2204.jpeg
# Removing entry with unreadable image: /content/images/image_2205.jpg
# Removing entry with unreadable image: /content/images/image_2206.jpeg
# Removing entry with unreadable image: /content/images/image_2207.jpg
# Removing entry with unreadable image: /content/images/image_2208.jpg
# Removing entry with unreadable image: /content/images/image_2209.jpg
# Removing entry with unreadable image: /content/images/image_2210.jpg
# Removing entry with unreadable image: /content/images/image_2211.jpeg
# Removing entry with unreadable image: /content/images/image_2212.jpeg
# Removing entry with unreadable image: /content/images/image_2213.jpg
# Removing entry with unreadable image: /content/images/image_2214.jpg
# Removing entry with unreadable image: /content/images/image_2215.jpg
# Removing entry with unreadable image: /content/images/image_2216.jpg
# Removing entry with unreadable image: /content/images/image_2217.jpg
# Removing entry with unreadable image: /content/images/image_2218.jpg
# Removing entry with unreadable image: /content/images/image_2219.jpg
# Removing entry with unreadable image: /content/images/image_2220.jpg
# Removing entry with unreadable image: /content/images/image_2221.jpg
# Removing entry with unreadable image: /content/images/image_2222.jpg
# Removing entry with unreadable image: /content/images/image_2223.jpg
# Removing entry with unreadable image: /content/images/image_2224.jpg
# Removing entry with unreadable image: /content/images/image_2225.jpg
# Removing entry with unreadable image: /content/images/image_2226.png
# Removing entry with unreadable image: /content/images/image_2227.jpg
# Removing entry with unreadable image: /content/images/image_2228.jpg
# Removing entry with unreadable image: /content/images/image_2229.jpg
# Removing entry with unreadable image: /content/images/image_2230.jpg
# Removing entry with unreadable image: /content/images/image_2231.jpg
# Removing entry with unreadable image: /content/images/image_2232.jpg
# Removing entry with unreadable image: /content/images/image_2233.png
# Removing entry with unreadable image: /content/images/image_2234.png
# Removing entry with unreadable image: /content/images/image_2235.png
# Removing entry with unreadable image: /content/images/image_2236.png
# Removing entry with unreadable image: /content/images/image_2237.png
# Removing entry with unreadable image: /content/images/image_2238.png
# Removing entry with unreadable image: /content/images/image_2239.jpg
# Removing entry with unreadable image: /content/images/image_2240.png
# Removing entry with unreadable image: /content/images/image_2241.jpg
# Removing entry with unreadable image: /content/images/image_2242.png
# Removing entry with unreadable image: /content/images/image_2243.jpg
# Removing entry with unreadable image: /content/images/image_2244.jpg
# Removing entry with unreadable image: /content/images/image_2245.jpg
# Removing entry with unreadable image: /content/images/image_2246.jpg
# Removing entry with unreadable image: /content/images/image_2247.jpeg
# Removing entry with unreadable image: /content/images/image_2248.png
# Removing entry with unreadable image: /content/images/image_2249.png
# Removing entry with unreadable image: /content/images/image_2250.jpg
# Removing entry with unreadable image: /content/images/image_2251.jpg
# Removing entry with unreadable image: /content/images/image_2252.jpg
# Removing entry with unreadable image: /content/images/image_2253.jpg
# Removing entry with unreadable image: /content/images/image_2254.png
# Removing entry with unreadable image: /content/images/image_2255.jpg
# Removing entry with unreadable image: /content/images/image_2256.png
# Removing entry with unreadable image: /content/images/image_2257.png
# Removing entry with unreadable image: /content/images/image_2258.png
# Removing entry with unreadable image: /content/images/image_2259.jpg
# Removing entry with unreadable image: /content/images/image_2260.png
# Removing entry with unreadable image: /content/images/image_2261.jpg
# Removing entry with unreadable image: /content/images/image_2262.png
# Removing entry with unreadable image: /content/images/image_2263.png
# Removing entry with unreadable image: /content/images/image_2264.png
# Removing entry with unreadable image: /content/images/image_2265.jpg
# Removing entry with unreadable image: /content/images/image_2266.png
# Removing entry with unreadable image: /content/images/image_2267.png
# Removing entry with unreadable image: /content/images/image_2268.jpg
# Removing entry with unreadable image: /content/images/image_2269.jpg
# Removing entry with unreadable image: /content/images/image_2270.jpg
# Removing entry with unreadable image: /content/images/image_2271.jpg
# Removing entry with unreadable image: /content/images/image_2272.jpg
# Removing entry with unreadable image: /content/images/image_2273.jpg
# Removing entry with unreadable image: /content/images/image_2274.jpeg
# Removing entry with unreadable image: /content/images/image_2275.jpeg
# Removing entry with unreadable image: /content/images/image_2276.jpeg
# Removing entry with unreadable image: /content/images/image_2277.jpeg
# Removing entry with unreadable image: /content/images/image_2278.jpg
# Removing entry with unreadable image: /content/images/image_2279.jpg
# Removing entry with unreadable image: /content/images/image_2280.jpeg
# Removing entry with unreadable image: /content/images/image_2281.jpg
# Removing entry with unreadable image: /content/images/image_2282.jpg
# Removing entry with unreadable image: /content/images/image_2283.jpeg
# Removing entry with unreadable image: /content/images/image_2284.jpg
# Removing entry with unreadable image: /content/images/image_2285.jpg
# Removing entry with unreadable image: /content/images/image_2286.jpg
# Removing entry with unreadable image: /content/images/image_2287.jpg
# Removing entry with unreadable image: /content/images/image_2288.png
# Removing entry with unreadable image: /content/images/image_2289.jpg
# Removing entry with unreadable image: /content/images/image_2290.jpg
# Removing entry with unreadable image: /content/images/image_2291.jpg
# Removing entry with unreadable image: /content/images/image_2292.png
# Removing entry with unreadable image: /content/images/image_2293.jpg
# Removing entry with unreadable image: /content/images/image_2294.jpg
# Removing entry with unreadable image: /content/images/image_2295.jpg
# Removing entry with unreadable image: /content/images/image_2296.png
# Removing entry with unreadable image: /content/images/image_2297.jpg
# Removing entry with unreadable image: /content/images/image_2298.jpg
# Removing entry with unreadable image: /content/images/image_2299.jpg
# Removing entry with unreadable image: /content/images/image_2300.jpg
# Removing entry with unreadable image: /content/images/image_2301.png
# Removing entry with unreadable image: /content/images/image_2302.png
# Removing entry with unreadable image: /content/images/image_2303.png
# Removing entry with unreadable image: /content/images/image_2304.png
# Removing entry with unreadable image: /content/images/image_2305.png
# Removing entry with unreadable image: /content/images/image_2306.png
# Removing entry with unreadable image: /content/images/image_2307.png
# Removing entry with unreadable image: /content/images/image_2308.png
# Removing entry with unreadable image: /content/images/image_2309.jpg
# Removing entry with unreadable image: /content/images/image_2310.jpg
# Removing entry with unreadable image: /content/images/image_2311.png
# Removing entry with unreadable image: /content/images/image_2312.png
# Removing entry with unreadable image: /content/images/image_2313.jpg
# Removing entry with unreadable image: /content/images/image_2314.jpg
# Removing entry with unreadable image: /content/images/image_2315.png
# Removing entry with unreadable image: /content/images/image_2316.jpg
# Removing entry with unreadable image: /content/images/image_2317.jpg
# Removing entry with unreadable image: /content/images/image_2318.jpg
# Removing entry with unreadable image: /content/images/image_2319.jpg
# Removing entry with unreadable image: /content/images/image_2320.jpg
# Removing entry with unreadable image: /content/images/image_2321.jpg
# Removing entry with unreadable image: /content/images/image_2322.jpg
# Removing entry with unreadable image: /content/images/image_2323.jpg
# Removing entry with unreadable image: /content/images/image_2324.jpg
# Removing entry with unreadable image: /content/images/image_2325.jpg
# Removing entry with unreadable image: /content/images/image_2326.jpg
# Removing entry with unreadable image: /content/images/image_2327.jpg
# Removing entry with unreadable image: /content/images/image_2328.jpeg
# Removing entry with unreadable image: /content/images/image_2329.jpg
# Removing entry with unreadable image: /content/images/image_2330.png
# Removing entry with unreadable image: /content/images/image_2331.jpeg
# Removing entry with unreadable image: /content/images/image_2332.jpg
# Removing entry with unreadable image: /content/images/image_2333.png
# Removing entry with unreadable image: /content/images/image_2334.jpg
# Removing entry with unreadable image: /content/images/image_2335.png
# Removing entry with unreadable image: /content/images/image_2336.jpg
# Removing entry with unreadable image: /content/images/image_2337.jpg
# Removing entry with unreadable image: /content/images/image_2338.jpg
# Removing entry with unreadable image: /content/images/image_2339.jpg
# Removing entry with unreadable image: /content/images/image_2340.png
# Removing entry with unreadable image: /content/images/image_2341.png
# Removing entry with unreadable image: /content/images/image_2342.png
# Removing entry with unreadable image: /content/images/image_2343.jpg
# Removing entry with unreadable image: /content/images/image_2344.jpg
# Removing entry with unreadable image: /content/images/image_2345.jpg
# Removing entry with unreadable image: /content/images/image_2346.jpg
# Removing entry with unreadable image: /content/images/image_2347.jpeg
# Removing entry with unreadable image: /content/images/image_2348.jpg
# Removing entry with unreadable image: /content/images/image_2349.jpg
# Removing entry with unreadable image: /content/images/image_2350.jpg
# Removing entry with unreadable image: /content/images/image_2351.png
# Removing entry with unreadable image: /content/images/image_2352.jpg
# Removing entry with unreadable image: /content/images/image_2353.jpg
# Removing entry with unreadable image: /content/images/image_2354.jpg
# Removing entry with unreadable image: /content/images/image_2355.jpg
# Removing entry with unreadable image: /content/images/image_2356.jpg
# Removing entry with unreadable image: /content/images/image_2357.jpg
# Removing entry with unreadable image: /content/images/image_2358.jpg
# Removing entry with unreadable image: /content/images/image_2359.jpg
# Removing entry with unreadable image: /content/images/image_2360.png
# Removing entry with unreadable image: /content/images/image_2361.jpg
# Removing entry with unreadable image: /content/images/image_2362.jpg
# Removing entry with unreadable image: /content/images/image_2363.jpg
# Removing entry with unreadable image: /content/images/image_2364.jpg
# Removing entry with unreadable image: /content/images/image_2365.jpg
# Removing entry with unreadable image: /content/images/image_2366.jpg
# Removing entry with unreadable image: /content/images/image_2367.jpg
# Removing entry with unreadable image: /content/images/image_2368.jpg
# Removing entry with unreadable image: /content/images/image_2369.jpg
# Removing entry with unreadable image: /content/images/image_2370.jpg
# Removing entry with unreadable image: /content/images/image_2371.jpg
# Removing entry with unreadable image: /content/images/image_2372.jpg
# Removing entry with unreadable image: /content/images/image_2373.jpg
# Removing entry with unreadable image: /content/images/image_2374.jpg
# Removing entry with unreadable image: /content/images/image_2375.png
# Removing entry with unreadable image: /content/images/image_2376.jpg
# Removing entry with unreadable image: /content/images/image_2377.png
# Removing entry with unreadable image: /content/images/image_2378.png
# Removing entry with unreadable image: /content/images/image_2379.jpg
# Removing entry with unreadable image: /content/images/image_2380.jpg
# Removing entry with unreadable image: /content/images/image_2381.jpg
# Removing entry with unreadable image: /content/images/image_2382.jpg
# Removing entry with unreadable image: /content/images/image_2383.jpg
# Removing entry with unreadable image: /content/images/image_2384.jpg
# Removing entry with unreadable image: /content/images/image_2385.jpg
# Removing entry with unreadable image: /content/images/image_2386.jpg
# Removing entry with unreadable image: /content/images/image_2387.jpg
# Removing entry with unreadable image: /content/images/image_2388.jpg
# Removing entry with unreadable image: /content/images/image_2389.png
# Removing entry with unreadable image: /content/images/image_2390.png
# Removing entry with unreadable image: /content/images/image_2391.png
# Removing entry with unreadable image: /content/images/image_2392.png
# Removing entry with unreadable image: /content/images/image_2393.png
# Removing entry with unreadable image: /content/images/image_2394.png
# Removing entry with unreadable image: /content/images/image_2395.png
# Removing entry with unreadable image: /content/images/image_2396.png
# Removing entry with unreadable image: /content/images/image_2397.png
# Removing entry with unreadable image: /content/images/image_2398.jpg
# Removing entry with unreadable image: /content/images/image_2399.png
# Removing entry with unreadable image: /content/images/image_2400.png
# Removing entry with unreadable image: /content/images/image_2401.png
# Removing entry with unreadable image: /content/images/image_2402.png
# Removing entry with unreadable image: /content/images/image_2403.png
# Removing entry with unreadable image: /content/images/image_2404.png
# Removing entry with unreadable image: /content/images/image_2405.jpg
# Removing entry with unreadable image: /content/images/image_2406.jpg
# Removing entry with unreadable image: /content/images/image_2407.png
# Removing entry with unreadable image: /content/images/image_2408.jpg
# Removing entry with unreadable image: /content/images/image_2409.png
# Removing entry with unreadable image: /content/images/image_2410.png
# Removing entry with unreadable image: /content/images/image_2411.png
# Removing entry with unreadable image: /content/images/image_2412.jpg
# Removing entry with unreadable image: /content/images/image_2413.jpg
# Removing entry with unreadable image: /content/images/image_2414.png
# Removing entry with unreadable image: /content/images/image_2415.jpg
# Removing entry with unreadable image: /content/images/image_2416.png
# Removing entry with unreadable image: /content/images/image_2417.png
# Removing entry with unreadable image: /content/images/image_2418.jpg
# Removing entry with unreadable image: /content/images/image_2419.jpg
# Removing entry with unreadable image: /content/images/image_2420.png
# Removing entry with unreadable image: /content/images/image_2421.png
# Removing entry with unreadable image: /content/images/image_2422.jpg
# Removing entry with unreadable image: /content/images/image_2423.jpg
# Removing entry with unreadable image: /content/images/image_2424.jpg
# Removing entry with unreadable image: /content/images/image_2425.jpg
# Removing entry with unreadable image: /content/images/image_2426.png
# Removing entry with unreadable image: /content/images/image_2427.png
# Removing entry with unreadable image: /content/images/image_2428.jpg
# Removing entry with unreadable image: /content/images/image_2429.png
# Removing entry with unreadable image: /content/images/image_2430.jpeg
# Removing entry with unreadable image: /content/images/image_2431.jpg
# Removing entry with unreadable image: /content/images/image_2432.jpeg
# Removing entry with unreadable image: /content/images/image_2433.jpg
# Removing entry with unreadable image: /content/images/image_2434.jpg
# Removing entry with unreadable image: /content/images/image_2435.jpg
# Removing entry with unreadable image: /content/images/image_2436.jpg
# Removing entry with unreadable image: /content/images/image_2437.jpg
# Removing entry with unreadable image: /content/images/image_2438.jpg
# Removing entry with unreadable image: /content/images/image_2439.jpeg
# Removing entry with unreadable image: /content/images/image_2440.jpg
# Removing entry with unreadable image: /content/images/image_2441.jpg
# Removing entry with unreadable image: /content/images/image_2442.jpg
# Removing entry with unreadable image: /content/images/image_2443.jpg
# Removing entry with unreadable image: /content/images/image_2444.jpg
# Removing entry with unreadable image: /content/images/image_2445.jpg
# Removing entry with unreadable image: /content/images/image_2446.jpeg
# Removing entry with unreadable image: /content/images/image_2447.jpg
# Removing entry with unreadable image: /content/images/image_2448.jpg
# Removing entry with unreadable image: /content/images/image_2449.jpg
# Removing entry with unreadable image: /content/images/image_2450.jpg
# Removing entry with unreadable image: /content/images/image_2451.jpg
# Removing entry with unreadable image: /content/images/image_2452.jpg
# Removing entry with unreadable image: /content/images/image_2453.jpg
# Removing entry with unreadable image: /content/images/image_2454.jpg
# Removing entry with unreadable image: /content/images/image_2455.jpg
# Removing entry with unreadable image: /content/images/image_2456.jpg
# Removing entry with unreadable image: /content/images/image_2457.jpg
# Removing entry with unreadable image: /content/images/image_2458.jpg
# Removing entry with unreadable image: /content/images/image_2459.jpg
# Removing entry with unreadable image: /content/images/image_2460.jpg
# Removing entry with unreadable image: /content/images/image_2461.jpeg
# Removing entry with unreadable image: /content/images/image_2462.jpg
# Removing entry with unreadable image: /content/images/image_2463.png
# Removing entry with unreadable image: /content/images/image_2464.jpg
# Removing entry with unreadable image: /content/images/image_2465.png
# Removing entry with unreadable image: /content/images/image_2466.jpg
# Removing entry with unreadable image: /content/images/image_2467.jpg
# Removing entry with unreadable image: /content/images/image_2468.jpg
# Removing entry with unreadable image: /content/images/image_2469.png
# Removing entry with unreadable image: /content/images/image_2470.jpg
# Removing entry with unreadable image: /content/images/image_2471.jpg
# Removing entry with unreadable image: /content/images/image_2472.jpg
# Removing entry with unreadable image: /content/images/image_2473.jpg
# Removing entry with unreadable image: /content/images/image_2474.jpg
# Removing entry with unreadable image: /content/images/image_2475.jpg
# Removing entry with unreadable image: /content/images/image_2476.jpg
# Removing entry with unreadable image: /content/images/image_2477.jpg
# Removing entry with unreadable image: /content/images/image_2478.jpg
# Removing entry with unreadable image: /content/images/image_2479.jpg
# Removing entry with unreadable image: /content/images/image_2480.jpg
# Removing entry with unreadable image: /content/images/image_2481.jpg
# Removing entry with unreadable image: /content/images/image_2482.jpg
# Removing entry with unreadable image: /content/images/image_2483.jpg
# Removing entry with unreadable image: /content/images/image_2484.jpg
# Removing entry with unreadable image: /content/images/image_2485.png
# Removing entry with unreadable image: /content/images/image_2486.jpg
# Removing entry with unreadable image: /content/images/image_2487.jpg
# Removing entry with unreadable image: /content/images/image_2488.jpg
# Removing entry with unreadable image: /content/images/image_2489.jpg
# Removing entry with unreadable image: /content/images/image_2490.png
# Removing entry with unreadable image: /content/images/image_2491.jpg
# Removing entry with unreadable image: /content/images/image_2492.jpg
# Removing entry with unreadable image: /content/images/image_2493.jpg
# Removing entry with unreadable image: /content/images/image_2494.jpg
# Removing entry with unreadable image: /content/images/image_2495.jpg
# Removing entry with unreadable image: /content/images/image_2496.jpg
# Removing entry with unreadable image: /content/images/image_2497.png
# Removing entry with unreadable image: /content/images/image_2498.jpg
# Removing entry with unreadable image: /content/images/image_2499.jpg
# Removing entry with unreadable image: /content/images/image_2500.jpg
# Removing entry with unreadable image: /content/images/image_2501.png
# Removing entry with unreadable image: /content/images/image_2502.jpg
# Removing entry with unreadable image: /content/images/image_2503.jpg
# Removing entry with unreadable image: /content/images/image_2504.jpg
# Removing entry with unreadable image: /content/images/image_2505.jpg
# Removing entry with unreadable image: /content/images/image_2506.jpg
# Removing entry with unreadable image: /content/images/image_2507.jpg
# Removing entry with unreadable image: /content/images/image_2508.jpg
# Removing entry with unreadable image: /content/images/image_2509.jpg
# Removing entry with unreadable image: /content/images/image_2510.jpg
# Removing entry with unreadable image: /content/images/image_2511.jpg
# Removing entry with unreadable image: /content/images/image_2512.jpg
# Removing entry with unreadable image: /content/images/image_2513.jpg
# Removing entry with unreadable image: /content/images/image_2514.jpg
# Removing entry with unreadable image: /content/images/image_2515.jpg
# Removing entry with unreadable image: /content/images/image_2516.jpg
# Removing entry with unreadable image: /content/images/image_2517.jpeg
# Removing entry with unreadable image: /content/images/image_2518.jpg
# Removing entry with unreadable image: /content/images/image_2519.jpg
# Removing entry with unreadable image: /content/images/image_2520.jpg
# Removing entry with unreadable image: /content/images/image_2521.jpg
# Removing entry with unreadable image: /content/images/image_2522.jpg
# Removing entry with unreadable image: /content/images/image_2523.jpg
# Removing entry with unreadable image: /content/images/image_2524.jpg
# Removing entry with unreadable image: /content/images/image_2525.jpg
# Removing entry with unreadable image: /content/images/image_2526.jpg
# Removing entry with unreadable image: /content/images/image_2527.jpg
# Removing entry with unreadable image: /content/images/image_2528.jpg
# Removing entry with unreadable image: /content/images/image_2529.jpg
# Removing entry with unreadable image: /content/images/image_2530.jpg
# Removing entry with unreadable image: /content/images/image_2531.jpg
# Removing entry with unreadable image: /content/images/image_2532.jpg
# Removing entry with unreadable image: /content/images/image_2533.jpg
# Removing entry with unreadable image: /content/images/image_2534.jpg
# Removing entry with unreadable image: /content/images/image_2535.jpeg
# Removing entry with unreadable image: /content/images/image_2536.jpg
# Removing entry with unreadable image: /content/images/image_2537.png
# Removing entry with unreadable image: /content/images/image_2538.jpg
# Removing entry with unreadable image: /content/images/image_2539.jpg
# Removing entry with unreadable image: /content/images/image_2540.jpeg
# Removing entry with unreadable image: /content/images/image_2541.jpg
# Removing entry with unreadable image: /content/images/image_2542.jpg
# Removing entry with unreadable image: /content/images/image_2543.jpg
# Removing entry with unreadable image: /content/images/image_2544.jpg
# Removing entry with unreadable image: /content/images/image_2545.jpg
# Removing entry with unreadable image: /content/images/image_2546.jpg
# Removing entry with unreadable image: /content/images/image_2547.jpg
# Removing entry with unreadable image: /content/images/image_2548.jpg
# Removing entry with unreadable image: /content/images/image_2549.jpg
# Removing entry with unreadable image: /content/images/image_2550.jpg
# Removing entry with unreadable image: /content/images/image_2551.jpg
# Removing entry with unreadable image: /content/images/image_2552.jpg
# Removing entry with unreadable image: /content/images/image_2553.jpg
# Removing entry with unreadable image: /content/images/image_2554.jpg
# Removing entry with unreadable image: /content/images/image_2555.jpg
# Removing entry with unreadable image: /content/images/image_2556.jpg
# Removing entry with unreadable image: /content/images/image_2557.jpg
# Removing entry with unreadable image: /content/images/image_2558.jpg
# Removing entry with unreadable image: /content/images/image_2559.jpg
# Removing entry with unreadable image: /content/images/image_2560.jpg
# Removing entry with unreadable image: /content/images/image_2561.jpg
# Removing entry with unreadable image: /content/images/image_2562.jpg
# Removing entry with unreadable image: /content/images/image_2563.jpg
# Removing entry with unreadable image: /content/images/image_2564.jpg
# Removing entry with unreadable image: /content/images/image_2565.jpg
# Removing entry with unreadable image: /content/images/image_2566.jpg
# Removing entry with unreadable image: /content/images/image_2567.jpg
# Removing entry with unreadable image: /content/images/image_2568.jpg
# Removing entry with unreadable image: /content/images/image_2569.jpg
# Removing entry with unreadable image: /content/images/image_2570.jpg
# Removing entry with unreadable image: /content/images/image_2571.jpg
# Removing entry with unreadable image: /content/images/image_2572.jpg
# Removing entry with unreadable image: /content/images/image_2573.jpg
# Removing entry with unreadable image: /content/images/image_2574.jpg
# Removing entry with unreadable image: /content/images/image_2575.jpg
# Removing entry with unreadable image: /content/images/image_2576.jpg
# Removing entry with unreadable image: /content/images/image_2577.jpg
# Removing entry with unreadable image: /content/images/image_2578.jpg
# Removing entry with unreadable image: /content/images/image_2579.jpg
# Removing entry with unreadable image: /content/images/image_2580.jpg
# Removing entry with unreadable image: /content/images/image_2581.jpg
# Removing entry with unreadable image: /content/images/image_2582.png
# Removing entry with unreadable image: /content/images/image_2583.jpg
# Removing entry with unreadable image: /content/images/image_2584.jpg
# Removing entry with unreadable image: /content/images/image_2585.jpg
# Removing entry with unreadable image: /content/images/image_2586.jpg
# Removing entry with unreadable image: /content/images/image_2587.jpg
# Removing entry with unreadable image: /content/images/image_2588.jpg
# Removing entry with unreadable image: /content/images/image_2589.jpg
# Removing entry with unreadable image: /content/images/image_2590.jpg
# Removing entry with unreadable image: /content/images/image_2591.jpg
# Removing entry with unreadable image: /content/images/image_2592.jpg
# Removing entry with unreadable image: /content/images/image_2593.jpg
# Removing entry with unreadable image: /content/images/image_2594.png
# Removing entry with unreadable image: /content/images/image_2595.jpg
# Removing entry with unreadable image: /content/images/image_2596.jpg
# Removing entry with unreadable image: /content/images/image_2597.png
# Removing entry with unreadable image: /content/images/image_2598.png
# Removing entry with unreadable image: /content/images/image_2599.png
# Removing entry with unreadable image: /content/images/image_2600.png
# Removing entry with unreadable image: /content/images/image_2601.png
# Removing entry with unreadable image: /content/images/image_2602.jpg
# Removing entry with unreadable image: /content/images/image_2603.png
# Removing entry with unreadable image: /content/images/image_2604.jpg
# Removing entry with unreadable image: /content/images/image_2605.jpg
# Removing entry with unreadable image: /content/images/image_2606.png
# Removing entry with unreadable image: /content/images/image_2607.jpg
# Removing entry with unreadable image: /content/images/image_2608.jpg
# Removing entry with unreadable image: /content/images/image_2609.jpg
# Removing entry with unreadable image: /content/images/image_2610.jpg
# Removing entry with unreadable image: /content/images/image_2611.jpg
# Removing entry with unreadable image: /content/images/image_2612.jpg
# Removing entry with unreadable image: /content/images/image_2613.jpg
# Removing entry with unreadable image: /content/images/image_2614.jpg
# Removing entry with unreadable image: /content/images/image_2615.jpg
# Removing entry with unreadable image: /content/images/image_2616.jpg
# Removing entry with unreadable image: /content/images/image_2617.jpg
# Removing entry with unreadable image: /content/images/image_2618.jpg
# Removing entry with unreadable image: /content/images/image_2619.jpg
# Removing entry with unreadable image: /content/images/image_2620.png
# Removing entry with unreadable image: /content/images/image_2621.png
# Removing entry with unreadable image: /content/images/image_2622.jpg
# Removing entry with unreadable image: /content/images/image_2623.jpg
# Removing entry with unreadable image: /content/images/image_2624.png
# Removing entry with unreadable image: /content/images/image_2625.jpg
# Removing entry with unreadable image: /content/images/image_2626.jpg
# Removing entry with unreadable image: /content/images/image_2627.jpg
# Removing entry with unreadable image: /content/images/image_2628.jpg
# Removing entry with unreadable image: /content/images/image_2629.jpg
# Removing entry with unreadable image: /content/images/image_2630.jpg
# Removing entry with unreadable image: /content/images/image_2631.jpg
# Removing entry with unreadable image: /content/images/image_2632.jpg
# Removing entry with unreadable image: /content/images/image_2633.jpg
# Removing entry with unreadable image: /content/images/image_2634.png
# Removing entry with unreadable image: /content/images/image_2635.png
# Removing entry with unreadable image: /content/images/image_2636.jpg
# Removing entry with unreadable image: /content/images/image_2637.jpg
# Removing entry with unreadable image: /content/images/image_2638.jpg
# Removing entry with unreadable image: /content/images/image_2639.jpg
# Removing entry with unreadable image: /content/images/image_2640.jpg
# Removing entry with unreadable image: /content/images/image_2641.jpg
# Removing entry with unreadable image: /content/images/image_2642.jpg
# Removing entry with unreadable image: /content/images/image_2643.jpg
# Removing entry with unreadable image: /content/images/image_2644.jpg
# Removing entry with unreadable image: /content/images/image_2645.jpg
# Removing entry with unreadable image: /content/images/image_2646.jpg
# Removing entry with unreadable image: /content/images/image_2647.jpg
# Removing entry with unreadable image: /content/images/image_2648.jpg
# Removing entry with unreadable image: /content/images/image_2649.jpg
# Removing entry with unreadable image: /content/images/image_2650.jpg
# Removing entry with unreadable image: /content/images/image_2651.jpg
# Removing entry with unreadable image: /content/images/image_2652.jpg
# Removing entry with unreadable image: /content/images/image_2653.jpg
# Removing entry with unreadable image: /content/images/image_2654.png
# Removing entry with unreadable image: /content/images/image_2655.jpg
# Removing entry with unreadable image: /content/images/image_2656.jpg
# Removing entry with unreadable image: /content/images/image_2657.jpg
# Removing entry with unreadable image: /content/images/image_2658.png
# Removing entry with unreadable image: /content/images/image_2659.jpg
# Removing entry with unreadable image: /content/images/image_2660.jpg
# Removing entry with unreadable image: /content/images/image_2661.png
# Removing entry with unreadable image: /content/images/image_2662.jpg
# Removing entry with unreadable image: /content/images/image_2663.png
# Removing entry with unreadable image: /content/images/image_2664.jpg
# Removing entry with unreadable image: /content/images/image_2665.png
# Removing entry with unreadable image: /content/images/image_2666.jpg
# Removing entry with unreadable image: /content/images/image_2667.jpg
# Removing entry with unreadable image: /content/images/image_2668.jpg
# Removing entry with unreadable image: /content/images/image_2669.jpg
# Removing entry with unreadable image: /content/images/image_2670.jpg
# Removing entry with unreadable image: /content/images/image_2671.jpg
# Removing entry with unreadable image: /content/images/image_2672.png
# Removing entry with unreadable image: /content/images/image_2673.jpg
# Removing entry with unreadable image: /content/images/image_2674.jpg
# Removing entry with unreadable image: /content/images/image_2675.png
# Removing entry with unreadable image: /content/images/image_2676.jpg
# Removing entry with unreadable image: /content/images/image_2677.png
# Removing entry with unreadable image: /content/images/image_2678.png
# Removing entry with unreadable image: /content/images/image_2679.png
# Removing entry with unreadable image: /content/images/image_2680.jpg
# Removing entry with unreadable image: /content/images/image_2681.png
# Removing entry with unreadable image: /content/images/image_2682.jpg
# Removing entry with unreadable image: /content/images/image_2683.jpg
# Removing entry with unreadable image: /content/images/image_2684.png
# Removing entry with unreadable image: /content/images/image_2685.jpg
# Removing entry with unreadable image: /content/images/image_2686.jpg
# Removing entry with unreadable image: /content/images/image_2687.jpg
# Removing entry with unreadable image: /content/images/image_2688.jpg
# Removing entry with unreadable image: /content/images/image_2689.jpg
# Removing entry with unreadable image: /content/images/image_2690.jpg
# Removing entry with unreadable image: /content/images/image_2691.png
# Removing entry with unreadable image: /content/images/image_2692.jpg
# Removing entry with unreadable image: /content/images/image_2693.jpg
# Removing entry with unreadable image: /content/images/image_2694.png
# Removing entry with unreadable image: /content/images/image_2695.jpg
# Removing entry with unreadable image: /content/images/image_2696.jpg
# Removing entry with unreadable image: /content/images/image_2697.jpg
# Removing entry with unreadable image: /content/images/image_2698.jpg
# ...
# Removing entry with unreadable image: /content/images/image_6770.jpg
# Removing entry with unreadable image: /content/images/image_6771.jpg
# Removing entry with unreadable image: /content/images/image_6772.jpg
# Removing entry with unreadable image: /content/images/image_6773.jpg
# Removing entry with unreadable image: /content/images/image_6774.jpg
# Removing entry with unreadable image: /content/images/image_6775.png
# Removing entry with unreadable image: /content/images/image_6776.jpg
# Removing entry with unreadable image: /content/images/image_6777.png
# Removing entry with unreadable image: /content/images/image_6778.jpg
# Removing entry with unreadable image: /content/images/image_6779.png
# Removing entry with unreadable image: /content/images/image_6780.jpg
# Removing entry with unreadable image: /content/images/image_6781.jpg
# Removing entry with empty or invalid caption: /content/images/image_6782.jpg
# Removing entry with unreadable image: /content/images/image_6783.jpg
# Removing entry with unreadable image: /content/images/image_6784.jpg
# Removing entry with empty or invalid caption: /content/images/image_6785.jpg
# Removing entry with unreadable image: /content/images/image_6786.jpg
# Removing entry with empty or invalid caption: /content/images/image_6787.jpg
# Removing entry with unreadable image: /content/images/image_6788.jpg
# Removing entry with unreadable image: /content/images/image_6789.jpg
# Removing entry with unreadable image: /content/images/image_6790.jpg
# Removing entry with unreadable image: /content/images/image_6791.jpg
# Removing entry with unreadable image: /content/images/image_6792.jpg
# Removing entry with unreadable image: /content/images/image_6793.jpg
# Removing entry with unreadable image: /content/images/image_6794.jpg
# Removing entry with unreadable image: /content/images/image_6795.jpg
# Removing entry with unreadable image: /content/images/image_6796.jpg
# Removing entry with unreadable image: /content/images/image_6797.jpg
# Removing entry with unreadable image: /content/images/image_6798.jpg
# Removing entry with unreadable image: /content/images/image_6799.jpg
# Removing entry with unreadable image: /content/images/image_6800.png
# Removing entry with unreadable image: /content/images/image_6801.jpg
# Removing entry with unreadable image: /content/images/image_6802.jpg
# Removing entry with unreadable image: /content/images/image_6803.png
# Removing entry with unreadable image: /content/images/image_6804.jpg
# Removing entry with unreadable image: /content/images/image_6805.jpg
# Removing entry with unreadable image: /content/images/image_6806.jpg
# Removing entry with unreadable image: /content/images/image_6807.jpg
# Removing entry with unreadable image: /content/images/image_6808.jpg
# Removing entry with unreadable image: /content/images/image_6809.jpg
# Removing entry with unreadable image: /content/images/image_6810.jpeg
# Removing entry with unreadable image: /content/images/image_6811.jpg
# Removing entry with unreadable image: /content/images/image_6812.jpg
# Removing entry with unreadable image: /content/images/image_6813.jpg
# Removing entry with unreadable image: /content/images/image_6814.jpg
# Removing entry with unreadable image: /content/images/image_6815.jpg
# Removing entry with unreadable image: /content/images/image_6816.png
# Removing entry with unreadable image: /content/images/image_6817.jpg
# Removing entry with unreadable image: /content/images/image_6818.jpg
# Removing entry with unreadable image: /content/images/image_6819.jpg
# Removing entry with unreadable image: /content/images/image_6820.jpg
# Removing entry with unreadable image: /content/images/image_6821.jpg
# Removing entry with unreadable image: /content/images/image_6822.png
# Removing entry with unreadable image: /content/images/image_6823.jpg
# Removing entry with unreadable image: /content/images/image_6824.jpeg
# Removing entry with unreadable image: /content/images/image_6825.jpg
# Removing entry with unreadable image: /content/images/image_6826.png
# Removing entry with unreadable image: /content/images/image_6827.jpg
# Removing entry with unreadable image: /content/images/image_6828.jpg
# Removing entry with unreadable image: /content/images/image_6829.jpg
# Removing entry with unreadable image: /content/images/image_6830.png
# Removing entry with unreadable image: /content/images/image_6831.jpeg
# Removing entry with unreadable image: /content/images/image_6832.png
# Removing entry with unreadable image: /content/images/image_6833.jpg
# Removing entry with unreadable image: /content/images/image_6834.jpg
# Removing entry with unreadable image: /content/images/image_6835.jpg
# Removing entry with unreadable image: /content/images/image_6836.png
# Removing entry with unreadable image: /content/images/image_6837.jpg
# Removing entry with unreadable image: /content/images/image_6838.jpg
# Removing entry with unreadable image: /content/images/image_6839.png
# Removing entry with unreadable image: /content/images/image_6840.png
# Removing entry with unreadable image: /content/images/image_6841.png
# Removing entry with unreadable image: /content/images/image_6842.png
# Removing entry with unreadable image: /content/images/image_6843.jpg
# Removing entry with unreadable image: /content/images/image_6844.jpg
# Removing entry with unreadable image: /content/images/image_6845.jpg
# Removing entry with unreadable image: /content/images/image_6846.jpg
# Removing entry with unreadable image: /content/images/image_6847.png
# Removing entry with unreadable image: /content/images/image_6848.jpg
# Removing entry with unreadable image: /content/images/image_6849.jpg
# Removing entry with unreadable image: /content/images/image_6850.jpg
# Removing entry with unreadable image: /content/images/image_6851.jpg
# Removing entry with unreadable image: /content/images/image_6852.jpg
# Removing entry with unreadable image: /content/images/image_6853.jpeg
# Removing entry with unreadable image: /content/images/image_6854.jpg
# Removing entry with unreadable image: /content/images/image_6855.jpg
# Removing entry with unreadable image: /content/images/image_6856.jpeg
# Removing entry with unreadable image: /content/images/image_6857.jpg
# Removing entry with unreadable image: /content/images/image_6858.jpg
# Removing entry with unreadable image: /content/images/image_6859.png
# Removing entry with unreadable image: /content/images/image_6860.jpg
# Removing entry with unreadable image: /content/images/image_6861.jpg
# Removing entry with unreadable image: /content/images/image_6862.jpg
# Removing entry with unreadable image: /content/images/image_6863.jpg
# Removing entry with unreadable image: /content/images/image_6864.jpg
# Removing entry with unreadable image: /content/images/image_6865.png
# Removing entry with unreadable image: /content/images/image_6866.jpg
# Removing entry with unreadable image: /content/images/image_6867.png
# Removing entry with unreadable image: /content/images/image_6868.png
# Removing entry with unreadable image: /content/images/image_6869.jpg
# Removing entry with unreadable image: /content/images/image_6870.jpg
# Removing entry with unreadable image: /content/images/image_6871.jpg
# Removing entry with unreadable image: /content/images/image_6872.png
# Removing entry with unreadable image: /content/images/image_6873.jpg
# Removing entry with unreadable image: /content/images/image_6874.jpg
# Removing entry with unreadable image: /content/images/image_6875.jpg
# Removing entry with unreadable image: /content/images/image_6876.jpg
# Removing entry with unreadable image: /content/images/image_6877.jpg
# Removing entry with unreadable image: /content/images/image_6878.jpg
# Removing entry with unreadable image: /content/images/image_6879.png
# Removing entry with unreadable image: /content/images/image_6880.jpg
# Removing entry with unreadable image: /content/images/image_6881.jpg
# Removing entry with unreadable image: /content/images/image_6882.png
# Removing entry with unreadable image: /content/images/image_6883.png
# Removing entry with unreadable image: /content/images/image_6884.jpeg
# Removing entry with unreadable image: /content/images/image_6885.jpg
# Removing entry with unreadable image: /content/images/image_6886.jpg
# Removing entry with unreadable image: /content/images/image_6887.jpg
# Removing entry with unreadable image: /content/images/image_6888.jpg
# Removing entry with unreadable image: /content/images/image_6889.jpg
# Removing entry with unreadable image: /content/images/image_6890.jpg
# Removing entry with unreadable image: /content/images/image_6891.jpg
# Removing entry with unreadable image: /content/images/image_6892.jpeg
# Removing entry with unreadable image: /content/images/image_6893.jpg
# Removing entry with unreadable image: /content/images/image_6894.jpg
# Removing entry with unreadable image: /content/images/image_6895.jpeg
# Removing entry with unreadable image: /content/images/image_6896.png
# Removing entry with unreadable image: /content/images/image_6897.jpg
# Removing entry with unreadable image: /content/images/image_6898.jpg
# Removing entry with unreadable image: /content/images/image_6899.jpg
# Removing entry with unreadable image: /content/images/image_6900.jpg
# Removing entry with unreadable image: /content/images/image_6901.jpg
# Removing entry with unreadable image: /content/images/image_6902.jpg
# Removing entry with unreadable image: /content/images/image_6903.jpg
# Removing entry with unreadable image: /content/images/image_6904.jpg
# Removing entry with unreadable image: /content/images/image_6905.jpg
# Removing entry with unreadable image: /content/images/image_6906.jpeg
# Removing entry with unreadable image: /content/images/image_6907.jpg
# Removing entry with unreadable image: /content/images/image_6908.jpg
# Removing entry with unreadable image: /content/images/image_6909.png
# Removing entry with unreadable image: /content/images/image_6910.jpg
# Removing entry with unreadable image: /content/images/image_6911.jpg
# Removing entry with unreadable image: /content/images/image_6912.jpg
# Removing entry with unreadable image: /content/images/image_6913.jpg
# Removing entry with unreadable image: /content/images/image_6914.png
# Removing entry with unreadable image: /content/images/image_6915.jpg
# Removing entry with unreadable image: /content/images/image_6916.jpg
# Removing entry with unreadable image: /content/images/image_6917.jpg
# Removing entry with unreadable image: /content/images/image_6918.jpg
# Removing entry with unreadable image: /content/images/image_6919.jpg
# Removing entry with unreadable image: /content/images/image_6920.jpg
# Removing entry with unreadable image: /content/images/image_6921.jpg
# Removing entry with unreadable image: /content/images/image_6922.jpg
# Removing entry with unreadable image: /content/images/image_6923.jpg
# Removing entry with unreadable image: /content/images/image_6924.jpg
# Removing entry with unreadable image: /content/images/image_6925.jpg
# Removing entry with unreadable image: /content/images/image_6926.jpg
# Removing entry with unreadable image: /content/images/image_6927.jpg
# Removing entry with unreadable image: /content/images/image_6928.jpg
# Removing entry with unreadable image: /content/images/image_6929.jpg
# Removing entry with unreadable image: /content/images/image_6930.png
# Removing entry with unreadable image: /content/images/image_6931.jpg
# Removing entry with unreadable image: /content/images/image_6932.jpg
# Removing entry with unreadable image: /content/images/image_6933.jpg
# Removing entry with unreadable image: /content/images/image_6934.jpg
# Removing entry with unreadable image: /content/images/image_6935.jpg
# Removing entry with unreadable image: /content/images/image_6936.png
# Removing entry with unreadable image: /content/images/image_6937.jpg
# Removing entry with unreadable image: /content/images/image_6938.jpg
# Removing entry with unreadable image: /content/images/image_6939.jpg
# Removing entry with unreadable image: /content/images/image_6940.png
# Removing entry with unreadable image: /content/images/image_6941.jpg
# Removing entry with unreadable image: /content/images/image_6942.jpg
# Removing entry with unreadable image: /content/images/image_6943.jpg
# Removing entry with unreadable image: /content/images/image_6944.jpg
# Removing entry with unreadable image: /content/images/image_6945.jpg
# Removing entry with unreadable image: /content/images/image_6946.jpg
# Removing entry with unreadable image: /content/images/image_6947.jpg
# Removing entry with unreadable image: /content/images/image_6948.jpg
# Removing entry with unreadable image: /content/images/image_6949.png
# Removing entry with unreadable image: /content/images/image_6950.jpg
# Removing entry with unreadable image: /content/images/image_6951.jpg
# Removing entry with unreadable image: /content/images/image_6952.jpeg
# Removing entry with unreadable image: /content/images/image_6953.jpg
# Removing entry with unreadable image: /content/images/image_6954.png
# Removing entry with unreadable image: /content/images/image_6955.jpg
# Removing entry with unreadable image: /content/images/image_6956.png
# Removing entry with unreadable image: /content/images/image_6957.jpg
# Removing entry with unreadable image: /content/images/image_6958.jpg
# Removing entry with unreadable image: /content/images/image_6959.jpg
# Removing entry with unreadable image: /content/images/image_6960.jpg
# Removing entry with unreadable image: /content/images/image_6961.jpg
# Removing entry with unreadable image: /content/images/image_6962.jpg
# Removing entry with unreadable image: /content/images/image_6963.jpg
# Removing entry with unreadable image: /content/images/image_6964.jpg
# Removing entry with unreadable image: /content/images/image_6965.jpg
# Removing entry with unreadable image: /content/images/image_6966.png
# Removing entry with unreadable image: /content/images/image_6967.jpg
# Removing entry with unreadable image: /content/images/image_6968.png
# Removing entry with unreadable image: /content/images/image_6969.png
# Removing entry with unreadable image: /content/images/image_6970.jpg
# Removing entry with unreadable image: /content/images/image_6971.png
# Removing entry with unreadable image: /content/images/image_6972.jpg
# Removing entry with unreadable image: /content/images/image_6973.jpg
# Removing entry with unreadable image: /content/images/image_6974.png
# Removing entry with unreadable image: /content/images/image_6975.png
# Removing entry with unreadable image: /content/images/image_6976.png
# Removing entry with unreadable image: /content/images/image_6977.png
# Removing entry with unreadable image: /content/images/image_6978.png
# Removing entry with unreadable image: /content/images/image_6979.png
# Removing entry with unreadable image: /content/images/image_6980.png
# Removing entry with unreadable image: /content/images/image_6981.png
# Removing entry with unreadable image: /content/images/image_6982.png
# Removing entry with unreadable image: /content/images/image_6983.jpg
# Removing entry with unreadable image: /content/images/image_6984.jpg
# Removing entry with unreadable image: /content/images/image_6985.jpg
# Removing entry with unreadable image: /content/images/image_6986.jpg
# Removing entry with unreadable image: /content/images/image_6987.jpg
# Removing entry with unreadable image: /content/images/image_6988.jpg
# Removing entry with unreadable image: /content/images/image_6989.jpg
# Removing entry with unreadable image: /content/images/image_6990.png
# Removing entry with unreadable image: /content/images/image_6991.jpg
# Removing entry with unreadable image: /content/images/image_6992.jpg
# Removed 6992 entries from the dataset.
# File not found: /content/images/4563, skipping...
# File not found: /content/images/941, skipping...
# File not found: /content/images/1014, skipping...
# File not found: /content/images/1268, skipping...
# File not found: /content/images/304, skipping...
# File not found: /content/images/1954, skipping...
# File not found: /content/images/3856, skipping...
# File not found: /content/images/2993, skipping...
# Text input shape: torch.Size([8, 128])
# Image shape: torch.Size([8, 3, 224, 224])
# Labels shape: torch.Size([8, 4])

# %%
# Load Pretrained Text Transformer (BERT or RoBERTa)
text_encoder = AutoModel.from_pretrained(TEXT_MODEL)

# Load Pretrained Image Model (ResNet50 or ViT)
IMAGE_MODEL = "resnet50"  # Change to "vit_base_patch16_224" for ViT
if IMAGE_MODEL == "resnet50":
    image_encoder = models.resnet50(pretrained=True)
    image_encoder.fc = nn.Identity()  # Remove classification head
elif IMAGE_MODEL == "vit_base_patch16_224":
    import timm
    image_encoder = timm.create_model("vit_base_patch16_224", pretrained=True)
    image_encoder.head = nn.Identity()  # Remove classification head
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:03<00:00, 28.2MB/s]

# %%
class MultimodalModel(nn.Module):
    def __init__(self, text_model, image_model, fusion_dim=512):
        super(MultimodalModel, self).__init__()
        self.text_encoder = text_model
        self.image_encoder = image_model

        text_embedding_dim = 768
        image_embedding_dim = 2048 if IMAGE_MODEL == "resnet50" else 768

        # Fusion layer
        self.fusion = nn.Linear(text_embedding_dim + image_embedding_dim, fusion_dim)
        self.relu = nn.ReLU()

        # Regression head (Predicts Humor, Sarcasm, Offense, Motivation)
        self.regression_head = nn.Linear(fusion_dim, 4)

    def forward(self, text_input_ids, text_attention_mask, image_tensor):
        # Text encoding
        text_features = self.text_encoder(input_ids=text_input_ids, attention_mask=text_attention_mask).last_hidden_state[:, 0, :]

        # Image encoding
        image_features = self.image_encoder(image_tensor).squeeze()

        # Fusion
        fused_features = torch.cat((text_features, image_features), dim=1)
        fused_output = self.relu(self.fusion(fused_features))

        # Regression head
        output = self.regression_head(fused_output)  # Outputs 4 values
        return output

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MultimodalModel(text_encoder, image_encoder).to(device)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.metrics import f1_score, accuracy_score

epochs = 5
for epoch in range(epochs):
    total_loss = 0
    all_preds = []
    all_labels = []

    model.train()

    for text_input_ids, text_attention_mask, images, labels in dataloader:
        text_input_ids, text_attention_mask, images, labels = (
            text_input_ids.to(device), text_attention_mask.to(device), images.to(device), labels.to(device)
        )

        optimizer.zero_grad()
        preds = model(text_input_ids, text_attention_mask, images)
        loss = criterion(preds, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # Store predictions & true labels for metric calculation
        all_preds.append(preds.detach().cpu().numpy())
        all_labels.append(labels.cpu().numpy())

    # Convert to numpy arrays
    all_preds = np.vstack(all_preds)  # Shape: (num_samples, 4)
    all_labels = np.vstack(all_labels)  # Shape: (num_samples, 4)

    # Convert Regression Outputs to Discrete Labels (Round to Nearest Integer)
    all_preds = np.round(all_preds).astype(int)

    # Compute Metrics for Each Category
    f1_humor = f1_score(all_labels[:, 0], all_preds[:, 0], average="macro")
    f1_sarcasm = f1_score(all_labels[:, 1], all_preds[:, 1], average="macro")
    f1_offense = f1_score(all_labels[:, 2], all_preds[:, 2], average="macro")
    f1_motivation = f1_score(all_labels[:, 3], all_preds[:, 3], average="macro")

    acc_humor = accuracy_score(all_labels[:, 0], all_preds[:, 0])
    acc_sarcasm = accuracy_score(all_labels[:, 1], all_preds[:, 1])
    acc_offense = accuracy_score(all_labels[:, 2], all_preds[:, 2])
    acc_motivation = accuracy_score(all_labels[:, 3], all_preds[:, 3])

    avg_f1 = (f1_humor + f1_sarcasm + f1_offense + f1_motivation) / 4
    avg_acc = (acc_humor + acc_sarcasm + acc_offense + acc_motivation) / 4

    # Print Metrics
    print(f"Epoch [{epoch+1}/{epochs}] - Loss: {total_loss / len(dataloader):.4f}")
    print(f"  F1 Scores  - Humor: {f1_humor:.4f}, Sarcasm: {f1_sarcasm:.4f}, Offense: {f1_offense:.4f}, Motivation: {f1_motivation:.4f}, Avg: {avg_f1:.4f}")
    print(f"  Accuracy   - Humor: {acc_humor:.4f}, Sarcasm: {acc_sarcasm:.4f}, Offense: {acc_offense:.4f}, Motivation: {acc_motivation:.4f}, Avg: {avg_acc:.4f}")
    print("-" * 80)
# Out:
# File not found: /content/images/4279, skipping...
# File not found: /content/images/1183, skipping...
# File not found: /content/images/573, skipping...
# File not found: /content/images/621, skipping...
# File not found: /content/images/3795, skipping...
# File not found: /content/images/6302, skipping...
# File not found: /content/images/3552, skipping...
# File not found: /content/images/6216, skipping...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-7424523b2cc9> in <cell line: 0>()
#      15
#      16         optimizer.zero_grad()
# ---> 17         preds = model(text_input_ids, text_attention_mask, images)
#      18         loss = criterion(preds, labels)
#      19         loss.backward()
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-28-5e0c84a26570> in forward(self, text_input_ids, text_attention_mask, image_tensor)
#      17     def forward(self, text_input_ids, text_attention_mask, image_tensor):
#      18         # Text encoding
# ---> 19         text_features = self.text_encoder(input_ids=text_input_ids, attention_mask=text_attention_mask).last_hidden_state[:, 0, :]
#      20
#      21         # Image encoding
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1076                 token_type_ids = torch.zeros(input_shape, dtype=torch.long, device=device)
#    1077
# -> 1078         embedding_output = self.embeddings(
#    1079             input_ids=input_ids,
#    1080             position_ids=position_ids,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, token_type_ids, position_ids, inputs_embeds, past_key_values_length)
#     209
#     210         if inputs_embeds is None:
# --> 211             inputs_embeds = self.word_embeddings(input_ids)
#     212         token_type_embeddings = self.token_type_embeddings(token_type_ids)
#     213
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     188
#     189     def forward(self, input: Tensor) -> Tensor:
# --> 190         return F.embedding(
#     191             input,
#     192             self.weight,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2549         # remove once script supports set_grad_enabled
#    2550         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2552
#    2553
#
# IndexError: index out of range in self
